# %% [markdown]
# ## pandas

# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('help_category.csv')

# %%
df
# Out:
#     help_category_id                                           name  \
# 0                  1                                     Geographic
# 1                  2                             Polygon properties
# 2                  3                              Numeric Functions
# 3                  4                                            WKT
# 4                  5                                        Plugins
# 5                  6                         Control flow functions
# 6                  7                                            MBR
# 7                  8                                   Transactions
# 8                  9                                  Help Metadata
# 9                 10                             Account Management
# 10                11                               Point properties
# 11                12                           Encryption Functions
# 12                13                          LineString properties
# ...

# %%
df.head(3)
# Out:
#    help_category_id                name  parent_category_id  url
# 0                 1          Geographic                   0  NaN
# 1                 2  Polygon properties                  35  NaN
# 2                 3   Numeric Functions                  39  NaN

# %%
df.parent_category_id.plot(kind='kde')

# %% [markdown]
# ## 爬虫

# %%
from bs4 import BeautifulSoup
import requests

# %%
response = requests.get('https://movie.douban.com/subject/26363254/')
bs =BeautifulSoup(response.text,'lxml')

name = bs.find('span',attrs={'property':'v:itemreviewed'}).text
score = bs.find('strong',attrs={'property':'v:average'}).text
summary = bs.find('div',id='link-report').text.strip()
mary = bs.find('span',attrs={'property':'v:summary'}).text.strip()

# %%
print(name)
print(score)
print(summary)
print(mary)
# Out:
# 战狼2
# 7.1
# 故事发生在非洲附近的大海上，主人公冷锋（吴京 饰）遭遇人生滑铁卢，被“开除军籍”，本想漂泊一生的他，正当他打算这么做的时候，一场突如其来的意外打破了他的计划，突然被卷入了一场非洲国家叛乱，本可以安全撤离，却因无法忘记曾经为军人的使命，孤身犯险冲回沦陷区，带领身陷屠杀中的同胞和难民，展开生死逃亡。随着斗争的持续，体内的狼性逐渐复苏，最终孤身闯入战乱区域，为同胞而战斗。
# 故事发生在非洲附近的大海上，主人公冷锋（吴京 饰）遭遇人生滑铁卢，被“开除军籍”，本想漂泊一生的他，正当他打算这么做的时候，一场突如其来的意外打破了他的计划，突然被卷入了一场非洲国家叛乱，本可以安全撤离，却因无法忘记曾经为军人的使命，孤身犯险冲回沦陷区，带领身陷屠杀中的同胞和难民，展开生死逃亡。随着斗争的持续，体内的狼性逐渐复苏，最终孤身闯入战乱区域，为同胞而战斗。

# %% [markdown]
# ## 机器学习 线性回归

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(1,10,20)
a = np.random.randint(1,10,20)

# %%
y = x * 4 + a

# %%
plt.plot(x,y,'o')

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x.reshape(20,1),y.reshape(20,1))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.predict(6)
# Out:
# array([[29.49047619]])

# %%
model.coef_
# Out:
# array([[3.98095238]])

# %%
model.intercept_
# Out:
# array([5.6047619])

# %%
3.98095238 * 6 + 5.6047619
# Out:
# 29.49047618

# %%
model.predict(10)
# Out:
# array([[45.41428571]])

# %%
model.coef_
# Out:
# array([[3.98095238]])

# %%
model.intercept_
# Out:
# array([5.6047619])

# %%
model.coef_ * 10 + model.intercept_
# Out:
# array([[45.41428571]])
